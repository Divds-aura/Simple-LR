# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df = pd.read_csv("sql.csv")

# %%
df
# Out:
#       RowsProcessed  QueryTime_ms
# 0           1702743       1029.74
# 1           4314572       2581.84
# 2           4936484       2983.12
# 3           2244489       1368.37
# 4           1580006        961.80
# ...             ...           ...
# 1495        4635678       2762.82
# 1496        3571963       2147.79
# 1497        2387935       1455.76
# 1498        1144106        634.93
# 1499        4488011       2701.35
#
# [1500 rows x 2 columns]

# %%
sns.scatterplot(x=df["RowsProcessed"],y=df["QueryTime_ms"])
# Out:
# <Axes: xlabel='RowsProcessed', ylabel='QueryTime_ms'>

# %%
df.isnull().sum()
# Out:
# RowsProcessed    0
# QueryTime_ms     0
# dtype: int64

# %%
df = df.dropna()

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#       RowsProcessed  QueryTime_ms
# 0           1702743       1029.74
# 1           4314572       2581.84
# 2           4936484       2983.12
# 3           2244489       1368.37
# 4           1580006        961.80
# ...             ...           ...
# 1495        4635678       2762.82
# 1496        3571963       2147.79
# 1497        2387935       1455.76
# 1498        1144106        634.93
# 1499        4488011       2701.35
#
# [1500 rows x 2 columns]

# %%
x = df[["QueryTime_ms"]]

# %%
y = df["QueryTime_ms"]

# %%
x
# Out:
#       QueryTime_ms
# 0          1029.74
# 1          2581.84
# 2          2983.12
# 3          1368.37
# 4           961.80
# ...            ...
# 1495       2762.82
# 1496       2147.79
# 1497       1455.76
# 1498        634.93
# 1499       2701.35
#
# [1500 rows x 1 columns]

# %%
y
# Out:
# 0       1029.74
# 1       2581.84
# 2       2983.12
# 3       1368.37
# 4        961.80
#          ...
# 1495    2762.82
# 1496    2147.79
# 1497    1455.76
# 1498     634.93
# 1499    2701.35
# Name: QueryTime_ms, Length: 1500, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r2 = r2_score(y_test,y_pred)

# %%
r2
# Out:
# 1.0
