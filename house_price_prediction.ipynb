# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("HousePricePrediction (1).csv")

# %%
df

# %%
df.sample(10)

# %%
df.iloc[916]

# %%
df["MSZoning"].unique()

# %%
df.fillna(0)

# %%
df.drop_duplicates()

# %%
df["MSZoning"].unique()

# %%
df["LotConfig"].unique()

# %%
df["BldgType"].unique()

# %%
df["Exterior1st"].unique()

# %%
df = df.fillna(0)

# %%
x = df.drop("SalePrice",axis=1)

# %%
y = df["SalePrice"]
y

# %%
x

# %%
x["MSZoning"].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 x["MSZoning"].unique()
#
# NameError: name 'x' is not defined

# %%
x["MSZoning"] = x["MSZoning"].map({"RL":1,"RM":2,"C (all)":3,"FV":4,"RH":5})

# %%
x["LotConfig"].unique()

# %%
x["LotConfig"] = x["LotConfig"].map({"Inside":1,"FR2":2,"Corner":3,"CulDSac":4,"FR3":5})

# %%
x["BldgType"].unique()

# %%
x["BldgType"] = x["BldgType"].map({"1Fam":1,"2fmCon":2,"Duplex":3,"TwnhsE":4,"Twnhs":5})

# %%
x["Exterior1st"].unique()

# %%
x["Exterior1st"] = x["Exterior1st"].map({"VinylSd":1,"MetalSd":2,"Wd Sdng":3,
                                         "HdBoard":4,"BrkFace":5,"WdShing":6,
                                        "CemntBd":7,"Plywood":8,"AsbShng":9,"Stucco":10,"BrkComm":11,
                                         "AsphShn":12,"Stone":13,"Imstucc":14,"CBlock":15})

# %%
x

# %%
y

# %%
x = x.fillna(0)

# %%
x.isnull().sum()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42)

# %%
X_train

# %%
y_train

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r2 = r2_score(y_test, y_pred)
r2

# %%
n = X_test.shape[0]
p = X_test.shape[1]

adj_r2 = 1 - ((1-r2)*(n-1))/(n-p-1)
adj_r2
